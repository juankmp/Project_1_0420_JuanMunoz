# %% [markdown]
# ### Data Analysis

# %%
import pandas as pd

# %%
#Importing the CSV processed v1
path_from= '/home/usuario/Documentos/Ironhack/Project_1_0420_JuanMunoz/data/processed'

#%difference w/out finisher
df_all = pd.read_csv(f'{path_from}/df_all.csv', sep=';') 

df_all[0:2]
# Out:
#                                    uuid education_level full_time_job  \
# 0  f6e7ee00-deac-0133-4de8-0a81e8b09a82              no            no
# 1  54f0f1c0-dda1-0133-a559-0a81e8b09a82            high           yes
#
#                            job_code                          job_title  \
# 0                        Unemployed                         Unemployed
# 1  861a9b9151e11362eb3c77ca914172d0  Automatic Data Processing Planner
#
#   country_code  country        rural  age gender has_children age_group  \
# 0           AT  Austria  countryside   61   male           no     40_65
# 1           AT  Austria        urban   57   male          yes     40_65
#
#              quest_awareness                    quest_vote  \
# 0  I know something about it              I would not vote
# 1      I understand it fully  I would probably vote for it
#
#                                       quest_effect  \
# 0                                None of the above
# 1  A basic income would not affect my work choices
#
#                                  quest_arguments_for  \
# 0                                  None of the above
# 1  It increases appreciation for household work a...
#
#                      quest_arguments_against new_age_group
# 0                          None of the above         56-65
# 1  It might encourage people to stop working         56-65

# %% [markdown]
# # Challenge 1 All Countries

# %%
df_result = df_all.groupby(['country','job_title','age_group']).agg({'uuid': ['count']})
df_result.columns = ['Quantity']
df_result = df_result.reset_index().sort_values(by='Quantity',ascending = False)
df_result.columns = ['Country','Job Title','Age group','Quantity']
#df_result.loc['Total']= df_result.sum(numeric_only=True, axis=0)
df_result_per = df_result.copy()
df_result_per['Percentage'] = round(df_result['Quantity'] / df_result['Quantity'].sum() * 100,2).astype(str) + '%'
df_result_wi = df_result_per.set_index('Country')

display(df_result) #dataframe without the percentage 
display(df_result_per) #dataframe with the percentage
display(df_result_wi) # Same as df_result_per but does not include index (without index)
# Out:
#              Country                                          Job Title  \
# 2953  United Kingdom                                         Unemployed
# 791           France                                         Unemployed
# 1068         Germany                                         Unemployed
# 1066         Germany                                         Unemployed
# 2620           Spain                                         Unemployed
# 1588           Italy                                         Unemployed
# 789           France                                         Unemployed
# 2951  United Kingdom                                         Unemployed
# 1067         Germany                                         Unemployed
# 1586           Italy                                         Unemployed
# 2031          Poland                                         Unemployed
# 790           France                                         Unemployed
# 2618           Spain                                         Unemployed
# 1587           Italy                                         Unemployed
# 2952  United Kingdom                                         Unemployed
# 2029          Poland                                         Unemployed
# 2619           Spain                                         Unemployed
# 1784     Netherlands                                         Unemployed
# 2030          Poland                                         Unemployed
# 1782     Netherlands                                         Unemployed
# 1286         Hungary                                         Unemployed
# 2311         Romania                                         Unemployed
# 1174          Greece                                         Unemployed
# 1783     Netherlands                                         Unemployed
# 2703          Sweden                                         Unemployed
# 150          Belgium                                         Unemployed
# 1172          Greece                                         Unemployed
# 152          Belgium                                         Unemployed
# 2313         Romania                                         Unemployed
# 2705          Sweden                                         Unemployed
# ...              ...                                                ...
# 355   Czech Republic                                  Database Designer
# 1594          Latvia                                     Data Architect
# 1573           Italy  Operations Officer, Afloat (Naval Tactical Dat...
# 1593          Latvia                                       Data Analyst
# Czech Republic                                Database Consultant     40_65
# Italy           Geographic Information Systems Database Admini...     14_25
# Czech Republic                               Database Coordinator     26_39
# Austria         Automatic Data Processing Customer Liaison (AD...     26_39
#
#                 Quantity Percentage
# Country
# United Kingdom       273      2.83%
# France               235      2.44%
# Germany              230      2.38%
# Germany              219      2.27%
# Spain                197      2.04%
# Italy                181      1.88%
# France               170      1.76%
# United Kingdom       161      1.67%
# Germany              160      1.66%
# Italy                141      1.46%
# Poland               139      1.44%
# France               130      1.35%
# Spain                128      1.33%
# Italy                124      1.29%
# United Kingdom       124      1.29%
# Poland               115      1.19%
# Spain                 98      1.02%
# Netherlands           79      0.82%
# Poland                70      0.73%
# Netherlands           52      0.54%
# Hungary               40      0.41%
# Romania               37      0.38%
# Greece                36      0.37%
# Netherlands           36      0.37%
# Sweden                35      0.36%
# Belgium               30      0.31%
# Greece                29       0.3%
# Belgium               29       0.3%
# Romania               28      0.29%
# Sweden                26      0.27%
# ...                  ...        ...
# Czech Republic         1      0.01%
# Latvia                 1      0.01%
# Italy                  1      0.01%
# Latvia                 1      0.01%
# Latvia                 1      0.01%
# Italy                  1      0.01%
# Czech Republic         1      0.01%
# Czech Republic         1      0.01%
# Czech Republic         1      0.01%
# Italy                  1      0.01%
# Italy                  1      0.01%
# Italy                  1      0.01%
# Italy                  1      0.01%
# Italy                  1      0.01%
# Italy                  1      0.01%
# Czech Republic         1      0.01%
# Czech Republic         1      0.01%
# Italy                  1      0.01%
# Italy                  1      0.01%
# Italy                  1      0.01%
# Italy                  1      0.01%
# Czech Republic         1      0.01%
# Czech Republic         1      0.01%
# Italy                  1      0.01%
# Italy                  1      0.01%
# Italy                  1      0.01%
# Czech Republic         1      0.01%
# Italy                  1      0.01%
# Czech Republic         1      0.01%
# Austria                1      0.01%
#
# [2954 rows x 4 columns]

# %%
df_result_wi.reset_index(level=0, inplace=True)
#df_result_wi['new_index'] = [x for x in range(1, len(df_result_wi.values)+1)]
#df_result_wi.index = df_result_wi['new_index']
df_result_wi
# Out:
#              Country                                          Job Title  \
# 0     United Kingdom                                         Unemployed
# 1             France                                         Unemployed
# 2            Germany                                         Unemployed
# 3            Germany                                         Unemployed
# 4              Spain                                         Unemployed
# 5              Italy                                         Unemployed
# 6             France                                         Unemployed
# 7     United Kingdom                                         Unemployed
# 8            Germany                                         Unemployed
# 9              Italy                                         Unemployed
# 10            Poland                                         Unemployed
# 11            France                                         Unemployed
# 12             Spain                                         Unemployed
# 13             Italy                                         Unemployed
# 14    United Kingdom                                         Unemployed
# 15            Poland                                         Unemployed
# 16             Spain                                         Unemployed
# 17       Netherlands                                         Unemployed
# 18            Poland                                         Unemployed
# 19       Netherlands                                         Unemployed
# 20           Hungary                                         Unemployed
# 21           Romania                                         Unemployed
# 22            Greece                                         Unemployed
# 23       Netherlands                                         Unemployed
# 24            Sweden                                         Unemployed
# 25           Belgium                                         Unemployed
# 26            Greece                                         Unemployed
# 27           Belgium                                         Unemployed
# 28           Romania                                         Unemployed
# 29            Sweden                                         Unemployed
# ...              ...                                                ...
# 2924  Czech Republic                                  Database Designer
# 2925          Latvia                                     Data Architect
# 2926           Italy  Operations Officer, Afloat (Naval Tactical Dat...
# 2927          Latvia                                       Data Analyst
# 2928          Latvia                              Clinical Data Manager
# 2929           Italy                          Voice and Data Technician
# 2930  Czech Republic                           Data Warehouse Architect
# 2931  Czech Republic                           Data Warehouse Developer
# 2932  Czech Republic                          Data Warehousing Engineer
# 2933           Italy                             Survey Data Technician
# 2934           Italy                        Scientific Database Curator
# 2935           Italy                         SQL Database Administrator
# 2936           Italy  SCADA Operator (Supervisory Control and Data A...
# 2937           Italy         Oracle Database Administrator (Oracle DBA)
# 2938           Italy         Oracle Database Administrator (Oracle DBA)
# 2939  Czech Republic                        Data Warehousing Specialist
# 2940  Czech Republic                               Database Coordinator
# 2941           Italy  Naval Tactical Data System--Combat Information...
# 2942           Italy                      Micro Computer Data Processor
# 2943           Italy                      Micro Computer Data Processor
# 2944           Italy                         Marketing Database Analyst
# 2945  Czech Republic                  Database Administration Associate
# 2946  Czech Republic                       Database Administrator (DBA)
# 2947           Italy                                Health Data Analyst
# 2948           Italy    Head of Information Systems and Data Processing
# 2949           Italy    Head of Information Systems and Data Processing
# 2950  Czech Republic                                Database Consultant
# 2951           Italy  Geographic Information Systems Database Admini...
# 2952  Czech Republic                               Database Coordinator
# 2953         Austria  Automatic Data Processing Customer Liaison (AD...
#
#      Age group  Quantity Percentage
# 0        40_65       273      2.83%
# 1        40_65       235      2.44%
# 2        40_65       230      2.38%
# 3        14_25       219      2.27%
# 4        40_65       197      2.04%
# 5        40_65       181      1.88%
# 6        14_25       170      1.76%
# 7        14_25       161      1.67%
# 8        26_39       160      1.66%
# 9        14_25       141      1.46%
# 10       40_65       139      1.44%
# 11       26_39       130      1.35%
# 12       14_25       128      1.33%
# 13       26_39       124      1.29%
# 14       26_39       124      1.29%
# 15       14_25       115      1.19%
# 16       26_39        98      1.02%
# 17       40_65        79      0.82%
# 18       26_39        70      0.73%
# 19       14_25        52      0.54%
# 20       40_65        40      0.41%
# 21       14_25        37      0.38%
# 22       40_65        36      0.37%
# 23       26_39        36      0.37%
# 24       14_25        35      0.36%
# 25       14_25        30      0.31%
# 26       14_25        29       0.3%
# 27       40_65        29       0.3%
# 28       40_65        28      0.29%
# 29       40_65        26      0.27%
# ...        ...       ...        ...
# 2924     40_65         1      0.01%
# 2925     26_39         1      0.01%
# 2926     26_39         1      0.01%
# 2927     40_65         1      0.01%
# 2928     40_65         1      0.01%
# 2929     14_25         1      0.01%
# 2930     40_65         1      0.01%
# 2931     40_65         1      0.01%
# 2932     40_65         1      0.01%
# 2933     26_39         1      0.01%
# 2934     26_39         1      0.01%
# 2935     14_25         1      0.01%
# 2936     40_65         1      0.01%
# 2937     26_39         1      0.01%
# 2938     14_25         1      0.01%
# 2939     40_65         1      0.01%
# 2940     40_65         1      0.01%
# 2941     40_65         1      0.01%
# 2942     40_65         1      0.01%
# 2943     26_39         1      0.01%
# 2944     40_65         1      0.01%
# 2945     40_65         1      0.01%
# 2946     14_25         1      0.01%
# 2947     40_65         1      0.01%
# 2948     26_39         1      0.01%
# 2949     14_25         1      0.01%
# 2950     40_65         1      0.01%
# 2951     14_25         1      0.01%
# 2952     26_39         1      0.01%
# 2953     26_39         1      0.01%
#
# [2954 rows x 5 columns]

# %% [markdown]
# # Challenge 1 selected Countries

# %%
filter = df_result['Country'] == 'Germany'

df_result_country = df_result[filter].sort_values(by='Quantity',ascending = False)
df_result_country['Percentage'] = round(df_result_country['Quantity'] / df_result_country['Quantity'].sum() * 100,2).astype(str) + '%'
df_result_country_wi = df_result_country.set_index('Country')


display(df_result_country)

display(df_result_country_wi)
# Out:
#       Country                                          Job Title Age group  \
# 1068  Germany                                         Unemployed     40_65
# 1066  Germany                                         Unemployed     14_25
# 1067  Germany                                         Unemployed     26_39
# 973   Germany                                  Database Engineer     40_65
# 879   Germany                                       Data Officer     40_65
# 919   Germany                            Data Storage Specialist     40_65
# 1059  Germany         Oracle Database Administrator (Oracle DBA)     40_65
# 948   Germany                    Database Administration Manager     26_39
# 1031  Germany  Geographic Information Systems Data Specialist...     40_65
# 976   Germany  Database Management System Specialist (DBMS Sp...     40_65
# 931   Germany                           Data Warehouse Architect     40_65
# 947   Germany                  Database Administration Associate     40_65
# 829   Germany                                     Data Architect     40_65
# 985   Germany                                   Database Modeler     40_65
# 900   Germany            Data Processing Systems Project Planner     40_65
# 851   Germany                                   Data Coordinator     40_65
# 876   Germany                           Data Modeling Specialist     40_65
# 929   Germany                             Data Warehouse Analyst     40_65
# 1058  Germany         Oracle Database Administrator (Oracle DBA)     26_39
# 934   Germany                           Data Warehouse Developer     40_65
# 1010  Germany  Electronic Data Interchange System Developer (...     40_65
# 960   Germany                                Database Consultant     40_65
# 1028  Germany  Geographic Information Systems Data Manager (G...     40_65
# 918   Germany                            Data Storage Specialist     26_39
# 842   Germany                        Data Communications Analyst     40_65
# 800   Germany    Automatic Data Processing Planner (ADP Planner)     40_65
# 826   Germany                                 Data Administrator     40_65
# 825   Germany                                 Data Administrator     26_39
# 819   Germany     Computer or Data Processing Systems Consultant     40_65
# 796   Germany                  Automatic Data Processing Planner     26_39
# ...       ...                                                ...       ...
# 1061  Germany  SCADA Operator (Supervisory Control and Data A...     40_65
# 1062  Germany  SCADA Technician (Supervisory Control and Data...     40_65
# 1063  Germany                         SQL Database Administrator     14_25
# 1065  Germany                             Survey Data Technician     40_65
# 1047  Germany                         Marketing Database Analyst     26_39
# 820   Germany                              Crime Data Specialist     14_25
# 816   Germany                   Clinical Trials Data Coordinator     40_65
# 815   Germany                              Clinical Data Manager     26_39
# 864   Germany                          Data Management Associate     26_39
# 852   Germany                        Data Entry Machine Operator     14_25
# 853   Germany                          Data Entry Representative     14_25
# 854   Germany                          Data Entry Representative     26_39
# 855   Germany                              Data Entry Supervisor     26_39
# 856   Germany                              Data Entry Supervisor     40_65
# 857   Germany                              Data Entry Technician     14_25
# 858   Germany                              Data Entry Technician     26_39
# 859   Germany                              Data Entry Technician     40_65
# 861   Germany                                         Data Keyer     14_25
# 869   Germany                            Data Management Manager     26_39
# 814   Germany     Clinical Data Management Manager (CDM Manager)     40_65
# 870   Germany                                       Data Manager     40_65
# 873   Germany                                       Data Modeler     40_65
# 863   Germany                          Data Management Associate     14_25
# 804   Germany                          Business Database Analyst     14_25
# 808   Germany                            Clinical Data Associate     40_65
# 809   Germany                          Clinical Data Coordinator     14_25
# 810   Germany                          Clinical Data Coordinator     26_39
# 811   Germany                          Clinical Data Coordinator     40_65
# 812   Germany        Clinical Data Management Associate Director     26_39
# 927   Germany                             Data Warehouse Analyst     14_25
#
#       Quantity Percentage
# 1068       230      16.2%
# 1066       219     15.42%
# 1067       160     11.27%
# 973         11      0.77%
# 879          9      0.63%
# 919          9      0.63%
# 1059         9      0.63%
# 948          9      0.63%
# 1031         8      0.56%
# 976          8      0.56%
# 931          8      0.56%
# 947          8      0.56%
# 829          8      0.56%
# 985          7      0.49%
# 900          7      0.49%
# 851          7      0.49%
# 876          7      0.49%
# 929          7      0.49%
# 1058         7      0.49%
# 934          7      0.49%
# 1010         7      0.49%
# 960          7      0.49%
# 1028         7      0.49%
# 918          6      0.42%
# 842          6      0.42%
# 800          6      0.42%
# 826          6      0.42%
# 825          6      0.42%
# 819          6      0.42%
# 796          6      0.42%
# ...        ...        ...
# 1061         1      0.07%
# 1062         1      0.07%
# 1063         1      0.07%
# 1065         1      0.07%
# 1047         1      0.07%
# 820          1      0.07%
# 816          1      0.07%
# 815          1      0.07%
# 864          1      0.07%
# 852          1      0.07%
# 853          1      0.07%
# 854          1      0.07%
# 855          1      0.07%
# 856          1      0.07%
# 857          1      0.07%
# 858          1      0.07%
# 859          1      0.07%
# 861          1      0.07%
# 869          1      0.07%
# 814          1      0.07%
# 870          1      0.07%
# 873          1      0.07%
# 863          1      0.07%
# 804          1      0.07%
# 808          1      0.07%
# 809          1      0.07%
# 810          1      0.07%
# 811          1      0.07%
# 812          1      0.07%
# 927          1      0.07%
#
# [278 rows x 5 columns]
#                                                  Job Title Age group  \
# Country
# Germany                                         Unemployed     40_65
# Germany                                         Unemployed     14_25
# Germany                                         Unemployed     26_39
# Germany                                  Database Engineer     40_65
# Germany                                       Data Officer     40_65
# Germany                            Data Storage Specialist     40_65
# Germany         Oracle Database Administrator (Oracle DBA)     40_65
# Germany                    Database Administration Manager     26_39
# Germany  Geographic Information Systems Data Specialist...     40_65
# Germany  Database Management System Specialist (DBMS Sp...     40_65
# Germany                           Data Warehouse Architect     40_65
# Germany                  Database Administration Associate     40_65
# Germany                                     Data Architect     40_65
# Germany                                   Database Modeler     40_65
# Germany            Data Processing Systems Project Planner     40_65
# Germany                                   Data Coordinator     40_65
# Germany                           Data Modeling Specialist     40_65
# Germany                             Data Warehouse Analyst     40_65
# Germany         Oracle Database Administrator (Oracle DBA)     26_39
# Germany                           Data Warehouse Developer     40_65
# Germany  Electronic Data Interchange System Developer (...     40_65
# Germany                                Database Consultant     40_65
# Germany  Geographic Information Systems Data Manager (G...     40_65
# Germany                            Data Storage Specialist     26_39
# Germany                        Data Communications Analyst     40_65
# Germany    Automatic Data Processing Planner (ADP Planner)     40_65
# Germany                                 Data Administrator     40_65
# Germany                                 Data Administrator     26_39
# Germany     Computer or Data Processing Systems Consultant     40_65
# Germany                  Automatic Data Processing Planner     26_39
# ...                                                    ...       ...
# Germany  SCADA Operator (Supervisory Control and Data A...     40_65
# Germany  SCADA Technician (Supervisory Control and Data...     40_65
# Germany                         SQL Database Administrator     14_25
# Germany                             Survey Data Technician     40_65
# Germany                         Marketing Database Analyst     26_39
# Germany                              Crime Data Specialist     14_25
# Germany                   Clinical Trials Data Coordinator     40_65
# Germany                              Clinical Data Manager     26_39
# Germany                          Data Management Associate     26_39
# Germany                        Data Entry Machine Operator     14_25
# Germany                          Data Entry Representative     14_25
# Germany                          Data Entry Representative     26_39
# Germany                              Data Entry Supervisor     26_39
# Germany                              Data Entry Supervisor     40_65
# Germany                              Data Entry Technician     14_25
# Germany                              Data Entry Technician     26_39
# Germany                              Data Entry Technician     40_65
# Germany                                         Data Keyer     14_25
# Germany                            Data Management Manager     26_39
# Germany     Clinical Data Management Manager (CDM Manager)     40_65
# Germany                                       Data Manager     40_65
# Germany                                       Data Modeler     40_65
# Germany                          Data Management Associate     14_25
# Germany                          Business Database Analyst     14_25
# Germany                            Clinical Data Associate     40_65
# Germany                          Clinical Data Coordinator     14_25
# Germany                          Clinical Data Coordinator     26_39
# Germany                          Clinical Data Coordinator     40_65
# Germany        Clinical Data Management Associate Director     26_39
# Germany                             Data Warehouse Analyst     14_25
#
#          Quantity Percentage
# Country
# Germany       230      16.2%
# Germany       219     15.42%
# Germany       160     11.27%
# Germany        11      0.77%
# Germany         9      0.63%
# Germany         9      0.63%
# Germany         9      0.63%
# Germany         9      0.63%
# Germany         8      0.56%
# Germany         8      0.56%
# Germany         8      0.56%
# Germany         8      0.56%
# Germany         8      0.56%
# Germany         7      0.49%
# Germany         7      0.49%
# Germany         7      0.49%
# Germany         7      0.49%
# Germany         7      0.49%
# Germany         7      0.49%
# Germany         7      0.49%
# Germany         7      0.49%
# Germany         7      0.49%
# Germany         7      0.49%
# Germany         6      0.42%
# Germany         6      0.42%
# Germany         6      0.42%
# Germany         6      0.42%
# Germany         6      0.42%
# Germany         6      0.42%
# Germany         6      0.42%
# ...           ...        ...
# Germany         1      0.07%
# Germany         1      0.07%
# Germany         1      0.07%
# Germany         1      0.07%
# Germany         1      0.07%
# Germany         1      0.07%
# Germany         1      0.07%
# Germany         1      0.07%
# Germany         1      0.07%
# Germany         1      0.07%
# Germany         1      0.07%
# Germany         1      0.07%
# Germany         1      0.07%
# Germany         1      0.07%
# Germany         1      0.07%
# Germany         1      0.07%
# Germany         1      0.07%
# Germany         1      0.07%
# Germany         1      0.07%
# Germany         1      0.07%
# Germany         1      0.07%
# Germany         1      0.07%
# Germany         1      0.07%
# Germany         1      0.07%
# Germany         1      0.07%
# Germany         1      0.07%
# Germany         1      0.07%
# Germany         1      0.07%
# Germany         1      0.07%
# Germany         1      0.07%
#
# [278 rows x 4 columns]

# %%
filter_2 = df_result['Country'] == 'Spain'
filter_3 = df_result['Job Title'] == 'Engineer'

df_result[filter_2 & filter_3]
# Out:
# Empty DataFrame
# Columns: [Country, Job Title, Age group, Quantity]
# Index: []

# %% [markdown]
# # For analysing and testing

# %%
df_result_test = df_all.groupby(['country']).agg({'uuid': ['count']})
df_result_test.columns = ['Quantity']
df_result_test = df_result_test.reset_index().sort_values(by='Quantity',ascending = False)
df_result_test.columns = ['Country','Quantity']
#df_result.loc['Total']= df_result.sum(numeric_only=True, axis=0)
df_result_test['Percentage'] = round(df_result_test['Quantity'] / df_result_test['Quantity'].sum() * 100,2).astype(str) + '%'
display(df_result_test) #dataframe without the percentage
# Out:
#            Country  Quantity Percentage
# 10         Germany      1420     14.72%
# 9           France      1248     12.93%
# 27  United Kingdom      1199     12.43%
# 14           Italy      1138     11.79%
# 25           Spain      1005     10.42%
# 20          Poland       860      8.91%
# 22         Romania       332      3.44%
# 19     Netherlands       331      3.43%
# 11          Greece       225      2.33%
# 12         Hungary       206      2.13%
# 21        Portugal       202      2.09%
# 5   Czech Republic       189      1.96%
# 1          Belgium       179      1.86%
# 26          Sweden       175      1.81%
# 2         Bulgaria       141      1.46%
# 0          Austria       133      1.38%
# 6          Denmark       119      1.23%
# 8          Finland       113      1.17%
# 23        Slovakia        93      0.96%
# 13         Ireland        90      0.93%
# 3          Croatia        87       0.9%
# 16       Lithuania        50      0.52%
# 15          Latvia        36      0.37%
# 24        Slovenia        28      0.29%
# 7          Estonia        18      0.19%
# 4           Cyprus        13      0.13%
# 17      Luxembourg        11      0.11%
# 18           Malta         8      0.08%

# %% [markdown]
# # AGE GROUP UNEMPLOYMENT ANALYSIS

# %%
df_result_test = df_all.groupby(['new_age_group']).agg({'uuid': ['count']})
df_result_test.columns = ['Total_Qty']
df_result_test = df_result_test.reset_index()
df_result_test.columns = ['new_age_group','Total_Qty']
df_result_test.loc['Total']= df_result_test.sum(numeric_only=True, axis=0)
df_result_test['%Share/Total'] = round(df_result_test['Total_Qty'] / df_result_test['Total_Qty'].sum() * 100 * 2,1).astype(str) + '%'
df_result_test['new_age_group'] = df_result_test['new_age_group'].fillna('Total')

filter = (df_all['full_time_job'] == 'no')
df_all_2 = df_all[filter]

df_result_test_2 = df_all_2.groupby(['new_age_group']).agg({'uuid': ['count']})
df_result_test_2.columns = ['Unemployed_Qty']
df_result_test_2 = df_result_test_2.reset_index()
df_result_test_2.columns = ['new_age_group','Unemployed_Qty']
df_result_test_2.loc['Total']= df_result_test_2.sum(numeric_only=True, axis=0)
df_result_test_2['%Share/Unemployed'] = round(df_result_test_2['Unemployed_Qty'] / df_result_test_2['Unemployed_Qty'].sum() * 100 * 2,1).astype(str) + '%'
df_result_test_2['new_age_group'] = df_result_test_2['new_age_group'].fillna('Total')




df_age_group_unemployment = pd.merge(df_result_test,df_result_test_2, how='left',on = 'new_age_group')
df_age_group_unemployment['%Unemployment rate'] = round(df_age_group_unemployment['Unemployed_Qty'] / df_age_group_unemployment['Total_Qty']*100,1).astype(str) + '%'

display(df_age_group_unemployment)
# Out:
#   new_age_group  Total_Qty %Share/Total  Unemployed_Qty %Share/Unemployed  \
# 0         14-18      631.0         6.5%           561.0             14.2%
# 1         19-25     1309.0        13.6%           754.0             19.1%
# 2         26-35     2135.0        22.1%           778.0             19.7%
# 3         36-45     2934.0        30.4%           788.0             20.0%
# 4         46-55     1926.0        20.0%           661.0             16.7%
# 5         56-65      714.0         7.4%           405.0             10.3%
# 6         Total     9649.0       100.0%          3947.0            100.0%
#
#   %Unemployment rate
# 0              88.9%
# 1              57.6%
# 2              36.4%
# 3              26.9%
# 4              34.3%
# 5              56.7%
# 6              40.9%

# %%
df_result_test = df_all.groupby(['age']).agg({'uuid': ['count']})
df_result_test.columns = ['Total_Qty']
df_result_test = df_result_test.reset_index()
df_result_test.columns = ['age','Total_Qty']
#df_result_test.loc['Total']= df_result_test.sum(numeric_only=True, axis=0)
df_result_test['%Share/Total'] = round(df_result_test['Total_Qty'] / df_result_test['Total_Qty'].sum() * 100 * 2,1).astype(str) + '%'
df_result_test['age'] = df_result_test['age'].fillna('Total')

filter = (df_all['full_time_job'] == 'no')
df_all_2 = df_all[filter]

df_result_test_2 = df_all_2.groupby(['age']).agg({'uuid': ['count']})
df_result_test_2.columns = ['Unemployed_Qty']
df_result_test_2 = df_result_test_2.reset_index()
df_result_test_2.columns = ['age','Unemployed_Qty']
#df_result_test_2.loc['Total']= df_result_test_2.sum(numeric_only=True, axis=0)
df_result_test_2['%Share/Unemployed'] = round(df_result_test_2['Unemployed_Qty'] / df_result_test_2['Unemployed_Qty'].sum() * 100 * 2,1).astype(str) + '%'
df_result_test_2['age'] = df_result_test_2['age'].fillna('Total')




df_age_unemployment = pd.merge(df_result_test,df_result_test_2, how='left',on = 'age')
df_age_unemployment['%Unemployment rate'] = round(df_age_unemployment['Unemployed_Qty'] / df_age_unemployment['Total_Qty']*100,1)#.astype(str) + '%'

display(df_age_unemployment)
# Out:
#     age  Total_Qty %Share/Total  Unemployed_Qty %Share/Unemployed  \
# 0    14         78         1.6%              72              3.6%
# 1    15        118         2.4%             109              5.5%
# 2    16        133         2.8%             121              6.1%
# 3    17        116         2.4%             103              5.2%
# 4    18        186         3.9%             156              7.9%
# 5    19        210         4.4%             149              7.6%
# 6    20        202         4.2%             136              6.9%
# 7    21        145         3.0%              90              4.6%
# 8    22        169         3.5%             107              5.4%
# 9    23        148         3.1%              86              4.4%
# 10   24        154         3.2%              65              3.3%
# 11   25        281         5.8%             121              6.1%
# 12   26        207         4.3%              88              4.5%
# 13   27        257         5.3%              91              4.6%
# 14   28        207         4.3%              77              3.9%
# 15   29        220         4.6%              77              3.9%
# 16   30        248         5.1%              81              4.1%
# 17   31        196         4.1%              82              4.2%
# 18   32        181         3.8%              70              3.5%
# 19   33        173         3.6%              66              3.3%
# 20   34        165         3.4%              64              3.2%
# 21   35        281         5.8%              82              4.2%
# 22   36        148         3.1%              48              2.4%
# 23   37        150         3.1%              49              2.5%
# 24   38        160         3.3%              36              1.8%
# 25   39        220         4.6%              61              3.1%
# 26   40        477         9.9%             119              6.0%
# 27   41        400         8.3%             117              5.9%
# 28   42        342         7.1%              75              3.8%
# 29   43        338         7.0%             112              5.7%
# 30   44        297         6.2%              74              3.7%
# 31   45        402         8.3%              97              4.9%
# 32   46        257         5.3%              86              4.4%
# 33   47        249         5.2%              82              4.2%
# 34   48        235         4.9%              78              4.0%
# 35   49        210         4.4%              68              3.4%
# 36   50        231         4.8%              73              3.7%
# 37   51        167         3.5%              49              2.5%
# 38   52        159         3.3%              66              3.3%
# 39   53        160         3.3%              66              3.3%
# 40   54        126         2.6%              40              2.0%
# 41   55        132         2.7%              53              2.7%
# 42   56         83         1.7%              36              1.8%
# 43   57         93         1.9%              45              2.3%
# 44   58         91         1.9%              50              2.5%
# 45   59        107         2.2%              51              2.6%
# 46   60         74         1.5%              42              2.1%
# 47   61         72         1.5%              46              2.3%
# 48   62         60         1.2%              39              2.0%
# 49   63         58         1.2%              35              1.8%
# 50   64         31         0.6%              24              1.2%
# 51   65         45         0.9%              37              1.9%
#
#     %Unemployment rate
# 0                 92.3
# 1                 92.4
# 2                 91.0
# 3                 88.8
# 4                 83.9
# 5                 71.0
# 6                 67.3
# 7                 62.1
# 8                 63.3
# 9                 58.1
# 10                42.2
# 11                43.1
# 12                42.5
# 13                35.4
# 14                37.2
# 15                35.0
# 16                32.7
# 17                41.8
# 18                38.7
# 19                38.2
# 20                38.8
# 21                29.2
# 22                32.4
# 23                32.7
# 24                22.5
# 25                27.7
# 26                24.9
# 27                29.2
# 28                21.9
# 29                33.1
# 30                24.9
# 31                24.1
# 32                33.5
# 33                32.9
# 34                33.2
# 35                32.4
# 36                31.6
# 37                29.3
# 38                41.5
# 39                41.2
# 40                31.7
# 41                40.2
# 42                43.4
# 43                48.4
# 44                54.9
# 45                47.7
# 46                56.8
# 47                63.9
# 48                65.0
# 49                60.3
# 50                77.4
# 51                82.2

# %%
# data vizualization
import matplotlib.pyplot as plt
import seaborn as sns

title = '% Unemployment rate by age'
fig, ax = plt.subplots(figsize=(15,8))
plt.title(title + "\n", fontsize=16)
barchart = sns.barplot(data=df_age_unemployment, x='age', y='%Unemployment rate')
#plt.title(title + "\n", fontsize=16)

# saving plots
path_to= '/home/usuario/Documentos/Ironhack/Project_1_0420_JuanMunoz/data/results'
fig = barchart.get_figure()
fig.savefig(f'{path_to}/{title}.png')

# %%
# saving plots
path_to= '/home/usuario/Documentos/Ironhack/Project_1_0420_JuanMunoz/data/results'

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages


fig, ax =plt.subplots(figsize=(12,4))
ax.axis('tight')
ax.axis('off')
the_table = ax.table(cellText=df_result_wi.values,colLabels=df_result_wi.columns,loc='center')

pp = PdfPages('/home/usuario/Documentos/Ironhack/Project_1_0420_JuanMunoz/data/results/prueba.pdf')
pp.savefig(fig, bbox_inches='tight')
pp.close()

# %%
# Out:
#                                               Job Title Age group  Quantity  \
# 1                                            Unemployed     40_65       273
# 2                                            Unemployed     40_65       235
# 3                                            Unemployed     40_65       230
# 4                                            Unemployed     14_25       219
# 5                                            Unemployed     40_65       197
# 6                                            Unemployed     40_65       181
# 7                                            Unemployed     14_25       170
# 8                                            Unemployed     14_25       161
# 9                                            Unemployed     26_39       160
# 10                                           Unemployed     14_25       141
# 11                                           Unemployed     40_65       139
# 12                                           Unemployed     26_39       130
# 13                                           Unemployed     14_25       128
# 14                                           Unemployed     26_39       124
# 15                                           Unemployed     26_39       124
# 16                                           Unemployed     14_25       115
# 17                                           Unemployed     26_39        98
# 18                                           Unemployed     40_65        79
# 19                                           Unemployed     26_39        70
# 20                                           Unemployed     14_25        52
# 21                                           Unemployed     40_65        40
# 22                                           Unemployed     14_25        37
# 23                                           Unemployed     40_65        36
# 24                                           Unemployed     26_39        36
# 25                                           Unemployed     14_25        35
# 26                                           Unemployed     14_25        30
# 27                                           Unemployed     14_25        29
# 28                                           Unemployed     40_65        29
# 29                                           Unemployed     40_65        28
# 30                                           Unemployed     40_65        26
# ...                                                 ...       ...       ...
# 2925                                  Database Designer     40_65         1
# 2926                                     Data Architect     26_39         1
# 2927  Operations Officer, Afloat (Naval Tactical Dat...     26_39         1
# 2928                                       Data Analyst     40_65         1
# 2929                              Clinical Data Manager     40_65         1
# 2930                          Voice and Data Technician     14_25         1
# 2931                           Data Warehouse Architect     40_65         1
# 2932                           Data Warehouse Developer     40_65         1
# 2933                          Data Warehousing Engineer     40_65         1
# 2934                             Survey Data Technician     26_39         1
# 2935                        Scientific Database Curator     26_39         1
# 2936                         SQL Database Administrator     14_25         1
# 2937  SCADA Operator (Supervisory Control and Data A...     40_65         1
# 2938         Oracle Database Administrator (Oracle DBA)     26_39         1
# 2939         Oracle Database Administrator (Oracle DBA)     14_25         1
# 2940                        Data Warehousing Specialist     40_65         1
# 2941                               Database Coordinator     40_65         1
# 2942  Naval Tactical Data System--Combat Information...     40_65         1
# 2943                      Micro Computer Data Processor     40_65         1
# 2944                      Micro Computer Data Processor     26_39         1
# 2945                         Marketing Database Analyst     40_65         1
# 2946                  Database Administration Associate     40_65         1
# 2947                       Database Administrator (DBA)     14_25         1
# 2948                                Health Data Analyst     40_65         1
# 2949    Head of Information Systems and Data Processing     26_39         1
# 2950    Head of Information Systems and Data Processing     14_25         1
# 2951                                Database Consultant     40_65         1
# 2952  Geographic Information Systems Database Admini...     14_25         1
# 2953                               Database Coordinator     26_39         1
# 2954  Automatic Data Processing Customer Liaison (AD...     26_39         1
#
#      Percentage
# 1         2.83%
# 2         2.44%
# 3         2.38%
# 4         2.27%
# 5         2.04%
# 6         1.88%
# 7         1.76%
# 8         1.67%
# 9         1.66%
# 10        1.46%
# 11        1.44%
# 12        1.35%
# 13        1.33%
# 14        1.29%
# 15        1.29%
# 16        1.19%
# 17        1.02%
# 18        0.82%
# 19        0.73%
# 20        0.54%
# 21        0.41%
# 22        0.38%
# 23        0.37%
# 24        0.37%
# 25        0.36%
# 26        0.31%
# 27         0.3%
# 28         0.3%
# 29        0.29%
# 30        0.27%
# ...         ...
# 2925      0.01%
# 2926      0.01%
# 2927      0.01%
# 2928      0.01%
# 2929      0.01%
# 2930      0.01%
# 2931      0.01%
# 2932      0.01%
# 2933      0.01%
# 2934      0.01%
# 2935      0.01%
# 2936      0.01%
# 2937      0.01%
# 2938      0.01%
# 2939      0.01%
# 2940      0.01%
# 2941      0.01%
# 2942      0.01%
# 2943      0.01%
# 2944      0.01%
# 2945      0.01%
# 2946      0.01%
# 2947      0.01%
# 2948      0.01%
# 2949      0.01%
# 2950      0.01%
# 2951      0.01%
# 2952      0.01%
# 2953      0.01%
# 2954      0.01%
#
# [2954 rows x 4 columns]

# %%
df_all['quest_arguments_against']
# Out:
# 0                                       None of the above
# 1               It might encourage people to stop working
# 2       Foreigners might come to my country and take a...
# 3                                       None of the above
# 4       It is impossible to finance | It might encoura...
# 5       It is impossible to finance | It might encoura...
# 6       Foreigners might come to my country and take a...
# 7       It might encourage people to stop working | Fo...
# 8       Foreigners might come to my country and take a...
# 9       Foreigners might come to my country and take a...
# 10      It is against the principle of linking merit a...
# 11      Foreigners might come to my country and take a...
# 12      It might encourage people to stop working | It...
# 13      It might encourage people to stop working | Fo...
# 14      It might encourage people to stop working | It...
# 15              It might encourage people to stop working
# 16      Foreigners might come to my country and take a...
# 17      It is against the principle of linking merit a...
# 18      It is impossible to finance | It might encoura...
# 19      It might encourage people to stop working | It...
# 20      Foreigners might come to my country and take a...
# 21      It might encourage people to stop working | It...
# 22                            It is impossible to finance
# 23              It might encourage people to stop working
# 24      Only the people who need it most should get so...
# 25              It might encourage people to stop working
# 26      Only the people who need it most should get so...
# 27      Only the people who need it most should get so...
# 28      It is impossible to finance | Foreigners might...
# 29                                      None of the above
#                               ...
# 9619    Foreigners might come to my country and take a...
# 9620    Foreigners might come to my country and take a...
# 9621                          It is impossible to finance
# 9622                          It is impossible to finance
# 9623                 It increases dependence on the state
# 9624                                    None of the above
# 9625    Foreigners might come to my country and take a...
# 9626                                    None of the above
# 9627    It increases dependence on the state | It migh...
# 9628    It is against the principle of linking merit a...
# 9629    It might encourage people to stop working | Fo...
# 9630    Foreigners might come to my country and take a...
# 9631    Foreigners might come to my country and take a...
# 9632                                    None of the above
# 9633    It is against the principle of linking merit a...
# 9634                                    None of the above
# 9635                                    None of the above
# 9636    It might encourage people to stop working | It...
# 9637    Foreigners might come to my country and take a...
# 9638            It might encourage people to stop working
# 9639    Foreigners might come to my country and take a...
# 9640    It is against the principle of linking merit a...
# 9641    Foreigners might come to my country and take a...
# 9642                                    None of the above
# 9643    It might encourage people to stop working | It...
# 9644                          It is impossible to finance
# 9645    It might encourage people to stop working | On...
# 9646                                    None of the above
# 9647    Foreigners might come to my country and take a...
# 9648    It might encourage people to stop working | It...
# Name: quest_arguments_against, Length: 9649, dtype: object

# %% [markdown]
# # quest_arguments_against Analysis

# %%
#function for analysis of arguments for:
def replace_comma(x):
    try:
        return x.replace(" ", "").replace(",", "-").lower()
    except:
        return x 

#creating a new column in the dataset    
df_all['quest_arguments_against_2'] = df_all['quest_arguments_against'].apply(replace_comma)

#function that shows the real unique values of the column dataframe
def list_unique(x):
    
    value_list = []
    for i in df_all[x]:
        value = i.split("|")
        value_list.append(value) 

    final_list = []
    for i in value_list:
        for j in i:
            final_list.append(j)
    return final_list

def remove_duplicates(x):
    return list(dict.fromkeys(x))

fin_list = list_unique('quest_arguments_against_2')
final_list = remove_duplicates(fin_list)

#print (final_list)
#len(final_list)


#Updates the new column as a list of responses
df_all['quest_arguments_against_2'] 
df_all['quest_arguments_against_2'] = df_all['quest_arguments_against_2'].str.replace("|",",")


value_list = []
for i in df_all['quest_arguments_against_2']:
    val = list(i.split(","))
    value_list.append(val)
     
df_all['quest_arguments_against_2'] = value_list


print(df_all['quest_arguments_against_2'])
# Out:
# 0                                        [noneoftheabove]
# 1                   [itmightencouragepeopletostopworking]
# 2       [foreignersmightcometomycountryandtakeadvantag...
# 3                                        [noneoftheabove]
# 4       [itisimpossibletofinance, itmightencouragepeop...
# 5       [itisimpossibletofinance, itmightencouragepeop...
# 6       [foreignersmightcometomycountryandtakeadvantag...
# 7       [itmightencouragepeopletostopworking, foreigne...
# 8       [foreignersmightcometomycountryandtakeadvantag...
# 9       [foreignersmightcometomycountryandtakeadvantag...
# 10      [itisagainsttheprincipleoflinkingmeritandrewar...
# 11      [foreignersmightcometomycountryandtakeadvantag...
# 12      [itmightencouragepeopletostopworking, itincrea...
# 13      [itmightencouragepeopletostopworking, foreigne...
# 14      [itmightencouragepeopletostopworking, itisimpo...
# 15                  [itmightencouragepeopletostopworking]
# 16      [foreignersmightcometomycountryandtakeadvantag...
# 17      [itisagainsttheprincipleoflinkingmeritandrewar...
# 18      [itisimpossibletofinance, itmightencouragepeop...
# 19      [itmightencouragepeopletostopworking, itisagai...
# 20      [foreignersmightcometomycountryandtakeadvantag...
# 21      [itmightencouragepeopletostopworking, itincrea...
# 22                              [itisimpossibletofinance]
# 23                  [itmightencouragepeopletostopworking]
# 24      [onlythepeoplewhoneeditmostshouldgetsomethingf...
# 25                  [itmightencouragepeopletostopworking]
# 26      [onlythepeoplewhoneeditmostshouldgetsomethingf...
# 27      [onlythepeoplewhoneeditmostshouldgetsomethingf...
# 28      [itisimpossibletofinance, foreignersmightcomet...
# 29                                       [noneoftheabove]
#                               ...
# 9619    [foreignersmightcometomycountryandtakeadvantag...
# 9620    [foreignersmightcometomycountryandtakeadvantag...
# 9621                            [itisimpossibletofinance]
# 9622                            [itisimpossibletofinance]
# 9623                    [itincreasesdependenceonthestate]
# 9624                                     [noneoftheabove]
# 9625    [foreignersmightcometomycountryandtakeadvantag...
# 9626                                     [noneoftheabove]
# 9627    [itincreasesdependenceonthestate, itmightencou...
# 9628    [itisagainsttheprincipleoflinkingmeritandrewar...
# 9629    [itmightencouragepeopletostopworking, foreigne...
# 9630    [foreignersmightcometomycountryandtakeadvantag...
# 9631    [foreignersmightcometomycountryandtakeadvantag...
# 9632                                     [noneoftheabove]
# 9633    [itisagainsttheprincipleoflinkingmeritandrewar...
# 9634                                     [noneoftheabove]
# 9635                                     [noneoftheabove]
# 9636    [itmightencouragepeopletostopworking, itincrea...
# 9637    [foreignersmightcometomycountryandtakeadvantag...
# 9638                [itmightencouragepeopletostopworking]
# 9639    [foreignersmightcometomycountryandtakeadvantag...
# 9640     [itisagainsttheprincipleoflinkingmeritandreward]
# 9641    [foreignersmightcometomycountryandtakeadvantag...
# 9642                                     [noneoftheabove]
# 9643    [itmightencouragepeopletostopworking, itincrea...
# 9644                            [itisimpossibletofinance]
# 9645    [itmightencouragepeopletostopworking, onlythep...
# 9646                                     [noneoftheabove]
# 9647    [foreignersmightcometomycountryandtakeadvantag...
# 9648    [itmightencouragepeopletostopworking, itisagai...
# Name: quest_arguments_against_2, Length: 9649, dtype: object

# %%
# count the times we have each answer in total
a= 0
b= 0
c= 0
d= 0
e= 0
f= 0
g= 0

for data in df_all['quest_arguments_against_2']:
    if len(list(data))==1:
        if data[0] == 'noneoftheabove':
            a += 1
        elif data[0] == 'itmightencouragepeopletostopworking':
            b += 1
        elif data[0] == 'foreignersmightcometomycountryandtakeadvantageofthebenefit':
            c += 1
        elif data[0] == 'itisimpossibletofinance':
            d += 1
        elif data[0] == 'itincreasesdependenceonthestate':
            e += 1
        elif data[0] == 'itisagainsttheprincipleoflinkingmeritandreward':
            f += 1
        elif data[0] == 'onlythepeoplewhoneeditmostshouldgetsomethingfromthestate':
            g += 1
    else:
        for datain in list(data):
            if datain == 'noneoftheabove':
                a += 1
            elif datain == 'itmightencouragepeopletostopworking':
                b += 1
            elif datain == 'foreignersmightcometomycountryandtakeadvantageofthebenefit':
                c += 1
            elif datain == 'itisimpossibletofinance':
                d += 1
            elif datain == 'itincreasesdependenceonthestate':
                e += 1
            elif datain == 'itisagainsttheprincipleoflinkingmeritandreward':
                f += 1
            elif datain == 'onlythepeoplewhoneeditmostshouldgetsomethingfromthestate':
                g += 1      

dict_result = {'None of the above':a,
'It might encourage people to stop working':b,
'Foreigners might come to my country and take advantage of the benefit':c, 
'It is impossible to finance':d,
'It increases dependence on the state':e,
'It is against the principle of linking merit and reward':f,
'Only the people who need it most should get something from the state':g}

df_answer_against = pd.DataFrame.from_dict(dict_result, orient='index',columns = ['Answers'])


df_answer_against['%Total'] = round((df_answer_against['Answers']/len(df_all['quest_arguments_against_2'])*100),2).astype(str) + '%'

df_answer_against = df_answer_against.sort_values('Answers', ascending=False)

# %% [markdown]
# # quest_arguments_for Analysis

# %%
#function for analysis of arguments for:
def replace_comma(x):
    try:
        return x.replace(" ", "").replace(",", "-").lower()
    except:
        return x 

#creating a new column in the dataset    
df_all['quest_arguments_for_2'] = df_all['quest_arguments_for'].apply(replace_comma)

#function that shows the real unique values of the column dataframe
def list_unique(x):
    
    value_list = []
    for i in df_all[x]:
        value = i.split("|")
        value_list.append(value) 

    final_list = []
    for i in value_list:
        for j in i:
            final_list.append(j)
    return final_list

def remove_duplicates(x):
    return list(dict.fromkeys(x))

fin_list = list_unique('quest_arguments_for_2')
final_list = remove_duplicates(fin_list)

print (final_list)
len(final_list)


#Updates the new column as a list of responses
df_all['quest_arguments_for_2'] 
df_all['quest_arguments_for_2'] = df_all['quest_arguments_for_2'].str.replace("|",",")


value_list = []
for i in df_all['quest_arguments_for_2']:
    val = list(i.split(","))
    value_list.append(val)
     
df_all['quest_arguments_for_2'] = value_list

print(value_list)
# Out:
# ['noneoftheabove', 'itincreasesappreciationforhouseholdworkandvolunteering', 'itencouragesfinancialindependenceandself-responsibility', 'itreducesanxietyaboutfinancingbasicneeds', 'itcreatesmoreequalityofopportunity', 'itreducesbureaucracyandadministrativeexpenses', 'itincreasessolidarity-becauseitisfundedbyeveryone']
# [['noneoftheabove'], ['itincreasesappreciationforhouseholdworkandvolunteering', 'itencouragesfinancialindependenceandself-responsibility', 'itreducesanxietyaboutfinancingbasicneeds'], ['itcreatesmoreequalityofopportunity'], ['itreducesanxietyaboutfinancingbasicneeds'], ['itreducesanxietyaboutfinancingbasicneeds'], ['itencouragesfinancialindependenceandself-responsibility', 'itreducesanxietyaboutfinancingbasicneeds'], ['itreducesanxietyaboutfinancingbasicneeds'], ['itincreasesappreciationforhouseholdworkandvolunteering', 'itreducesanxietyaboutfinancingbasicneeds'], ['itcreatesmoreequalityofopportunity', 'itreducesanxietyaboutfinancingbasicneeds', 'itreducesbureaucracyandadministrativeexpenses
# %%
# count the times we have each answer in total
a= 0
b= 0
c= 0
d= 0
e= 0
f= 0
g= 0

for data in df_all['quest_arguments_for_2']:
    if len(list(data))==1:
        if data[0] == 'noneoftheabove':
            a += 1
        elif data[0] == 'itincreasesappreciationforhouseholdworkandvolunteering':
            b += 1
        elif data[0] == 'itencouragesfinancialindependenceandself-responsibility':
            c += 1
        elif data[0] == 'itreducesanxietyaboutfinancingbasicneeds':
            d += 1
        elif data[0] == 'itcreatesmoreequalityofopportunity':
            e += 1
        elif data[0] == 'itreducesbureaucracyandadministrativeexpenses':
            f += 1
        elif data[0] == 'itincreasessolidarity-becauseitisfundedbyeveryone':
            g += 1
    else:
        for datain in list(data):
            if datain == 'noneoftheabove':
                a += 1
            elif datain == 'itincreasesappreciationforhouseholdworkandvolunteering':
                b += 1
            elif datain == 'itencouragesfinancialindependenceandself-responsibility':
                c += 1
            elif datain == 'itreducesanxietyaboutfinancingbasicneeds':
                d += 1
            elif datain == 'itcreatesmoreequalityofopportunity':
                e += 1
            elif datain == 'itreducesbureaucracyandadministrativeexpenses':
                f += 1
            elif datain == 'itincreasessolidarity-becauseitisfundedbyeveryone':
                g += 1      

dict_result = {'None of the above':a,
'It increases appreciation for household work and volunteering':b,
'It encourages financial independence and self-responsibility':c, 
'It reduces anxiety about financing basic needs':d,
'It creates more equality of opportunity':e,
'It reduces bureaucracy and administrative expenses':f,
'It increase ssolidarity because it is funded by everyone':g}

df_answer_for = pd.DataFrame.from_dict(dict_result, orient='index',columns = ['Answers'])


df_answer_for['%Total'] = round((df_answer_for['Answers']/len(df_all['quest_arguments_for_2'])*100),2).astype(str) + '%'

df_answer_for = df_answer_for.sort_values('Answers', ascending=False)

# %% [markdown]
# # Bonus 1

# %%
display(df_answer_for)
display(df_answer_against)
# Out:
#                                                     Answers  %Total
# It reduces anxiety about financing basic needs         3893  40.35%
# It creates more equality of opportunity                2955  30.62%
# None of the above                                      2163  22.42%
# It encourages financial independence and self-r...     2148  22.26%
# It increase ssolidarity because it is funded by...     2052  21.27%
# It increases appreciation for household work an...     2013  20.86%
# It reduces bureaucracy and administrative expenses     1510  15.65%
#                                                     Answers  %Total
# It might encourage people to stop working              4232  43.86%
# Foreigners might come to my country and take ad...     3341  34.63%
# It is impossible to finance                            3218  33.35%
# Only the people who need it most should get som...     3107   32.2%
# It increases dependence on the state                   2394  24.81%
# It is against the principle of linking merit an...     2082  21.58%
# None of the above                                      1381  14.31%

# %%
#Export the detail analysis result to a CSV
path_to= '/home/usuario/Documentos/Ironhack/Project_1_0420_JuanMunoz/data/results'
df_result_wi.to_csv(f'{path_to}/df_result_allcountries.csv',index = True, header=True, sep = ';')
df_result_country_wi.to_csv(f'{path_to}/df_result_one_country.csv',index = True, header=True, sep = ';')
df_answer_for.to_csv(f'{path_to}/df_answer_for.csv',index = False, header=True, sep = ';')
df_answer_against.to_csv(f'{path_to}/df_answer_against.csv',index = False, header=True, sep = ';')

# %% [markdown]
# prueba
